# %% [markdown]
# <img src="1.jpg"></img>
# <br>
# <img src="2.jpg"></img>
# <br>
# <img src="3.jpg"></img>
# <br>
# <img src="4.jpg"></img>
# <br>
# <img src="5.jpg"></img>
# <br>
# <img src="6.jpg"></img>
# <br>
# <img src="7.png"></img>
# <br>
# <img src="8.png"></img>
# <br>

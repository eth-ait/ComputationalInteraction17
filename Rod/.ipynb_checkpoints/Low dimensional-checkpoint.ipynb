# %%
import numpy as np
import sklearn
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pylab as pl
from itertools import cycle
# Out:
# /Users/rodmurraysmith/.local/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# After the fit(), the pca model exposes the singular vectors in the components_ attribute:

# %% [markdown]
# # Digits
# OK - lets try something more exciting than the Iris dataset (this is taken from https://github.com/oreillymedia/t-SNE-tutorial)

# %%
from sklearn import datasets
from sklearn import manifold
import matplotlib.patheffects as PathEffects
digits = datasets.load_digits()
digits.data.shape
#print(digits['DESCR'])

from sklearn.utils.extmath import _ravel
# Random state.
RS = 20150101

# %%
nrows, ncols = 2, 5
plt.figure(figsize=(6,3))
plt.gray()
for i in range(ncols * nrows):
    ax = plt.subplot(nrows, ncols, i + 1)
    ax.matshow(digits.images[i,...])
    plt.xticks([]); plt.yticks([])
    plt.title(digits.target[i])
plt.savefig('images/digits-generated.png', dpi=150)

# %% [markdown]
# Now let's run the t-SNE algorithm on the dataset. It just takes one line with scikit-learn.

# %%
# We first reorder the data points according to the handwritten numbers.
X = np.vstack([digits.data[digits.target==i]
               for i in range(10)])
y = np.hstack([digits.target[digits.target==i]
               for i in range(10)])
digits_proj = manifold.TSNE(random_state=RS).fit_transform(X)

# %% [markdown]
# Here is a utility function used to display the transformed dataset. The color of each point refers to the actual digit (of course, this information was not used by the dimensionality reduction algorithm).

# %%
def scatter(x, colors):
    # We choose a color palette with seaborn.
    palette = np.array(sns.color_palette("hls", 10))

    # We create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40,
                    c=palette[colors.astype(np.int)])
    plt.xlim(-25, 25)
    plt.ylim(-25, 25)
    ax.axis('off')
    ax.axis('tight')

    # We add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([
            PathEffects.Stroke(linewidth=5, foreground="w"),
            PathEffects.Normal()])
        txts.append(txt)

    return f, ax, sc, txts

scatter(digits_proj, y)
plt.savefig('images/digits_tsne-generated.png', dpi=120)

# %% [markdown]
# Observe that the images corresponding to the different digits are clearly separated into different clusters of points.

# %% [markdown]
# # Topic Goal
#
# We want to apply what you learned yesterday on **machine learning approaches to learning low-dimensional projections** to high-dimensional data from a human motion tracking example
#
# ## Human Motion capture data
# Let us now look at some data from human motion capture, to see if we can usefully view this high-dimensional data in a lower dimensional space.
#
# Although you have a large number of measurement points on a human body, that does not mean that each one is independent of the others.

# %%
# load in some motion data
from sklearn import manifold
import pandas as pd
# %matplotlib inline
from sklearn.utils.extmath import _ravel
# Random state.
RS = 20150101

X = pd.read_csv('handtracker/olddata/2016-6-6-9.20/data/trackerOutput5_pincer.txt')
Xbend = pd.read_csv('handtracker/olddata/2016-6-6-9.20/data/trackerOutput12_finger_bending.txt')
X.columns = ['t']+['x','y','z']*32+['c']
Xbend.columns = ['t']+['x','y','z']*32+['c']

X['t']= pd.to_datetime(X['t'], unit='us')
Xbend['t']= pd.to_datetime(Xbend['t'], unit='us')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-4af7efb730a0> in <module>()
#       7 RS = 20150101
#       8
# ----> 9 X = pd.read_csv('handtracker/olddata/2016-6-6-9.20/data/trackerOutput5_pincer.txt')
#      10 Xbend = pd.read_csv('handtracker/olddata/2016-6-6-9.20/data/trackerOutput12_finger_bending.txt')
#      11 X.columns = ['t']+['x','y','z']*32+['c']
#
# ...

# %% [markdown]
# We can plot this in parallel coordinates, but it isn't clear what the intrinsic dimensionality of the data is. How independent are these time-series?

# %%
X.plot(x='t', y=range(3,97,3),legend=False,title='z')
X.plot(x='t', y=range(2,97,3),legend=False,title='y')
X.plot(x='t', y=range(1,97,3),legend=False,title='x')

# %% [markdown]
# but what if we try to bring this down to two dimensions?

# %%
Xbend.columns = ['t']+['x','y','z']*32+['c']
Xbend.plot(x='t', y=range(3,97,3),legend=False,title='z')
Xbend.plot(x='t', y=range(2,97,3),legend=False,title='y')
Xbend.plot(x='t', y=range(1,97,3),legend=False,title='x')
plt.show()

# %% [markdown]
# so far we have been looking at each hand pose as a static hand configuration, so it is not picking up change of state. What if we apply some derivative operators to the time-series?

# %%
X_proj = manifold.TSNE(random_state=RS).fit_transform(X.iloc[:,1:96])
plt.plot(X_proj[:,0],X_proj[:,1],'.')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-478fb11d0544> in <module>()
# ----> 1 X_proj = manifold.TSNE(random_state=RS).fit_transform(X.iloc[:,1:96])
#       2 plt.plot(X_proj[:,0],X_proj[:,1],'.')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
Xbend_proj = manifold.TSNE(random_state=RS).fit_transform(Xbend.iloc[:,1:96])
plt.plot(Xbend_proj[:,0],Xbend_proj[:,1],'.')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize =(15,5))
pos=1
for i in range(1,50,10):
   ax = fig.add_subplot(1,5,pos, projection='3d')
   pos +=1
   ax.scatter(X.iloc[i, range(1,97,3)], X.iloc[i, range(2,97,3)], X.iloc[i, range(3,97,3)])

# %% [markdown]
# See the handTRK.py file for better animation

# %%
import csv
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib inline

fileName = 'handtracker/finger bending 3 times output30/'
#fileName = 'handtracker/hand movement left 10 times output35/'

Xacc = pd.read_csv(fileName+'imu_acc.txt')
Xpos = pd.read_csv(fileName+'trackerOutput30.txt')

Xpos.columns = ['t']+['x','y','z']*32+['c']
#Xpos['t']= pd.to_datetime(Xpos['t'], unit='us')

Xpos['t']=(Xpos['t']-Xpos['t'][0])/1e6 #zero at start, and convert from microseconds to seconds
Xpos.iloc[:,:].plot(y=range(2,97,3),legend=False,title='position')

# reshape data from 5 rows of 3 for each finger to 15 columns of acc data for each time sample
Nacc = 5*(len(Xacc.iloc[:,0])/5)  #deal with any incomplete tail data
Xacc = pd.DataFrame(np.reshape(np.array(Xacc.iloc[0:Nacc,:]),(Nacc/5,15)))
Nacc= Nacc/5
                                        
Xacc.columns = ['axt','ayt','azt','ax1','ay1','az1','ax2','ay2','az2','ax3','ay3','az3','ax4','ay4','az4']
Fs = 100
#Xacc['t']= np.array(range(0,Nacc))/Fs  # convert to seconds (assuming 100Hz sampling)

Xacc.iloc[:,:].plot(y=['ax1','ay1','az1'],legend=False,title='acceleration')

# %%
Xpos.iloc[200:700,:].plot(y=[26],legend=False,title='position')

# %%
import csv
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib inline

fileName = 'handtracker/new_data/finger bending 3 times output40/'
#fileName = 'handtracker/hand movement left 10 times output35/'

Xacc = pd.read_csv(fileName+'imu_acc.txt')
Xpos = pd.read_csv(fileName+'trackerOutput40.txt')

Xpos.columns = ['t']+['x','y','z']*32+['c']
#Xpos['t']= pd.to_datetime(Xpos['t'], unit='us')

Xpos['t']=(Xpos['t']-Xpos['t'][0])/1e6 #zero at start, and convert from microseconds to seconds
Xpos.iloc[:,:].plot(y=range(2,97,3),legend=False,title='position')

Nacc = len(Xacc.iloc[:,0]) #deal with any incomplete tail data


Xacc = Xacc.iloc[:,0:-1] # get rid of issues with trailing comma in file
Xacc.columns = ['t','axt','ayt','azt','ax1','ay1','az1','ax2','ay2','az2','ax3','ay3','az3','ax4','ay4','az4']
Fs = 100
#Xacc['t']= np.array(range(0,Nacc))/Fs  # convert to seconds (assuming 100Hz sampling)

Xacc.iloc[:,:].plot(x='t', y=['ax1','ay1','az1'],legend=False,title='acceleration')

# %%
import pykalman as pk
import seaborn as sns
from pykalman import KalmanFilter
kf = KalmanFilter(initial_state_mean=0, n_dim_obs=2)


noise = 1
Ts = Xpos.iloc[200]['t']-Xpos.iloc[199]['t']
t = Xpos.loc[100:400,'t']
measurements=Xpos.iloc[100:401,19]
kf = KalmanFilter(transition_matrices = [[1, Ts, 0], [0, 1, Ts], [0, 0, 1]], observation_matrices = [[1, 0.0, 0.0]],n_dim_obs=1)

kf = kf.em(measurements, n_iter=15) # learn the parameters of the Kalman Filter
(filtered_state_means, filtered_state_covariances) = kf.filter(measurements)
(smoothed_state_means, smoothed_state_covariances) = kf.smooth(measurements)

plt.plot(t, measurements, '.', t, smoothed_state_means[:,0],'-r',t, smoothed_state_means[:,1],'-k',t, smoothed_state_means[:,2],'-b')
Xacc.iloc[:,:].plot(y=['ax1','ay1','az1'],legend=False,title='acceleration')

# %% [markdown]
# #### The challenge - 1
#
# You should take the hand data and work out how many different gestures there are. Try extending the static representation of the hand to include higher order derivatives (velocity, acceleration) to see if these change the picture.

# %% [markdown]
# ## The challenge - 2
# You now have extra channels giving the acceleration of the fingers. Unfortunately the matching of sensors to fingers has become confused. Can you find the right matching of fingers to sensors?
#
# What could you use this sort of system for in an application?

# %%
# %load_ext autoreload
# %cd /Users/rodmurraysmith/SummerSchool2017/ComputationalInteraction17/Rod/Labs/handmodelling_ciss17
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import preprocessing.Pipelines as pipelines
import preprocessing.Representations as reps

import models.AutoEncoder as autoenc
import models.AutoEncoderQuat as autoencquat

from keras.objectives import mean_squared_error as mse_loss 
from models.objectives.QuaternionLoss import QuaternionLoss

import visualisations.VisAutoEncoder as vis
import preprocessing.Metadata as meta

import analysis.AutoEncoderEvaluation as ae_eval

import tools.SummerSchoolTools as summer_school_help


data_filepath = 'data/aalto_metronome.csv'
model_storage_path = 'export/models/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/rodmurraysmith/SummerSchool2017/ComputationalInteraction17/Rod/Labs/handmodelling_ciss17

# %% [markdown]
# # Load the data

# %%
data_raw = pipelines.load_aalto_hand_data(data_filepath)
# Out:
# Loaded 79150 rows with 85 columns from file:
# data/aalto_metronome.csv
# There are no missing values in this file.

# %% [markdown]
# # Preprocess the data

# %% [markdown]
# We prepare the data in two representations:
# - as x, y, z coordinates
# - as quaternions on a graph

# %%
data_xyz = pipelines.preprocess_aalto_hand_data(
    data_raw, 
    representation=reps.REPRESENTATION_XYZ)
# Out:
# 1. Added an origin column "Wrist_Origin" based on the mean of these columns: ['MetroArm_W_In', 'MetroArm_W_out']
# 2. Shifted the x/y/z coordinates so that they are relative to the origin column.
# 3. Merged the two hand center points.
# 4. Removed the original two hand center points.
# 5. Removed the extra arm points (E).
# 6. Reordered columns: non-feature columns first, then feature columns in order as specified in the metadata (see Metadata.py).
# 7. Removed the timestamp column ("Time"), leaving 78 columns.

# %%
data_quat = pipelines.preprocess_aalto_hand_data(
    data_raw, 
    representation=reps.REPRESENTATION_QUAT)
# Out:
# 1. Added an origin column "Wrist_Origin" based on the mean of these columns: ['MetroArm_W_In', 'MetroArm_W_out']
# 2. Shifted the x/y/z coordinates so that they are relative to the origin column.
# 3. Merged the two hand center points.
# 4. Removed the original two hand center points.
# 5. Removed the extra arm points (E).
# 6. Converted the data from x/y/z coordinates to quaternion representation (i.e. quaternion and distance per joint along skeleton graph)
# 7. Reordered columns: non-feature columns first, then feature columns in order as specified in the metadata (see Metadata.py).
# 8. Removed the timestamp column ("Time"), leaving 128 columns.

# %% [markdown]
# ## Split into training and test set

# %%
def split_train_test(data, ratio=0.75):
    N = len(data)
    split = int(ratio*N)
    data_train = data.iloc[:split]
    data_test = data.iloc[split:]
    return data_train, data_test

# %%
data_xyz_train, data_xyz_test = split_train_test(data_xyz, ratio=0.75)
data_quat_train, data_quat_test = split_train_test(data_quat, ratio=0.75)

# %% [markdown]
# # Create an auto encoder (x, y, z representation)

# %%
# %autoreload 2
ae_xyz = autoenc.AutoEncoder(
    input_dim=data_xyz.shape[1],
    coding_dims=[128, 64, 8], # number of units per coding layer (e.g. [128, 64, 9] creates a net 128-64-8-64-128)
    noise=0, # std deviation of Gaussian noise added to the input during training (set to 0 for no noise)
    dropout=[0,0,0], # set the dropout rate for the coding layers
    dropout_inputs=0, # if > 0, set the ratio of inputs to drop at random during training
    loss=mse_loss, # the chosen loss function (see keras.objectives for others losses)
    batch_size=100,
    name_tag='ae_xyz')
ae_xyz.model_ae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 78)                0
# _________________________________________________________________
# input_noise (GaussianNoiseHa (None, 78)                0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 78)                312
# _________________________________________________________________
# encoded_0 (Dense)            (None, 128)               10112
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 128)               512
# _________________________________________________________________
# encoded_0_act (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# encoded_0_drop (Dropout)     (None, 128)               0
# _________________________________________________________________
# encoded_1 (Dense)            (None, 64)                8256
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 64)                256
# _________________________________________________________________
# encoded_1_act (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# encoded_1_drop (Dropout)     (None, 64)                0
# _________________________________________________________________
# encoded (Dense)              (None, 8)                 520
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 8)                 32
# _________________________________________________________________
# encoded_act (LeakyReLU)      (None, 8)                 0
# _________________________________________________________________
# encoded_drop (Dropout)       (None, 8)                 0
# _________________________________________________________________
# decoded_0 (Dense)            (None, 64)                576
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 64)                256
# _________________________________________________________________
# decoded_0_act (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# decoded_0_drop (Dropout)     (None, 64)                0
# _________________________________________________________________
# decoded_1 (Dense)            (None, 128)               8320
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 128)               512
# _________________________________________________________________
# decoded_1_act (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# decoded_1_drop (Dropout)     (None, 128)               0
# _________________________________________________________________
# decoded (Dense)              (None, 78)                10062
# =================================================================
# Total params: 39,726.0
# Trainable params: 38,786.0
# Non-trainable params: 940.0
# _________________________________________________________________

# %% [markdown]
# ## Run training

# %%
ae_xyz.learning_rate = 0.001 
#if you change the learning rate, you must run training with recompile=True
ae_xyz.train_epochs(
    data=data_xyz_train.values,
    validation_data=data_xyz_test.values,
    epochs=10, repetitions=1,
    path=model_storage_path,
    clear_history=False,
    recompile=False)
ae_xyz.plot_history(offset=0)
# Out:
# Train on 59362 samples, validate on 19788 samples
# Epoch 1/10
# 59362/59362 [==============================] - 4s - loss: 0.0737 - val_loss: 0.0272
# Epoch 2/10
# 59362/59362 [==============================] - 4s - loss: 0.0183 - val_loss: 0.0113
# Epoch 3/10
# 59362/59362 [==============================] - 4s - loss: 0.0077 - val_loss: 0.0048
# Epoch 4/10
# 59362/59362 [==============================] - 4s - loss: 0.0032 - val_loss: 0.0019
# Epoch 5/10
# 59362/59362 [==============================] - 4s - loss: 7.5346e-04 - val_loss: 3.9030e-04
# Epoch 6/10
# 59362/59362 [==============================] - 4s - loss: 2.5007e-04 - val_loss: 2.8140e-04
# Epoch 7/10
# 59362/59362 [==============================] - 3s - loss: 2.0988e-04 - val_loss: 3.6852e-04
# Epoch 8/10
# 59362/59362 [==============================] - 4s - loss: 1.8743e-04 - val_loss: 0.0011
# Epoch 9/10
# 59362/59362 [==============================] - 4s - loss: 1.7590e-04 - val_loss: 3.2854e-04
# Epoch 10/10
# 59362/59362 [==============================] - 3s - loss: 1.6636e-04 - val_loss: 2.2711e-04
# Repetition 0 done.
# Model written to file: export/models/model_ae_78_128_64_8_b100_n00000_00000_ae_xyz.h5

# %% [markdown]
# ### or run the cell below to load an existing model

# %%
ae_xyz.load_from_file(model_storage_path + ae_xyz.model_name + '.h5')

# %% [markdown]
# # Create an auto encoder (quaternion representation)

# %%
# You can switch between training with this loss and mse_loss and compare the results:
quat_loss = QuaternionLoss().loss 

ae_quat = autoencquat.AutoEncoderQuat(
    coding_dims=[128, 64, 8], 
    noise=0,
    dropout=[0,0,0],
    dropout_inputs=0,
    loss=quat_loss,
    batch_size=100,
    name_tag='ae_quat')
ae_quat.model_ae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 103)               0
# _________________________________________________________________
# input_noise (GaussianNoiseHa (None, 103)               0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 103)               412
# _________________________________________________________________
# encoded_0 (Dense)            (None, 128)               13312
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 128)               512
# _________________________________________________________________
# encoded_0_act (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# encoded_0_drop (Dropout)     (None, 128)               0
# _________________________________________________________________
# encoded_1 (Dense)            (None, 64)                8256
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 64)                256
# _________________________________________________________________
# encoded_1_act (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# encoded_1_drop (Dropout)     (None, 64)                0
# _________________________________________________________________
# encoded (Dense)              (None, 8)                 520
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 8)                 32
# _________________________________________________________________
# encoded_act (LeakyReLU)      (None, 8)                 0
# _________________________________________________________________
# encoded_drop (Dropout)       (None, 8)                 0
# _________________________________________________________________
# decoded_0 (Dense)            (None, 64)                576
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 64)                256
# _________________________________________________________________
# decoded_0_act (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# decoded_0_drop (Dropout)     (None, 64)                0
# _________________________________________________________________
# decoded_1 (Dense)            (None, 128)               8320
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 128)               512
# _________________________________________________________________
# decoded_1_act (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# decoded_1_drop (Dropout)     (None, 128)               0
# _________________________________________________________________
# decoded (Dense)              (None, 103)               13287
# =================================================================
# Total params: 46,251.0
# Trainable params: 45,261.0
# Non-trainable params: 990.0
# _________________________________________________________________

# %% [markdown]
# ## Run training

# %%
ae_quat.learning_rate = 0.001 
#if you change the learning rate, you must run training with recompile=True
ae_quat.train_epochs(
    data=data_quat_train.values,
    validation_data=data_quat_test.values,
    epochs=10, repetitions=1,
    path=model_storage_path,
    clear_history=False,
    recompile=False)
ae_quat.plot_history(offset=0)
# Out:
# Train on 59362 samples, validate on 19788 samples
# Epoch 1/10
# 59362/59362 [==============================] - 6s - loss: 9.1732 - val_loss: 5.8691
# Epoch 2/10
# 59362/59362 [==============================] - 5s - loss: 4.9810 - val_loss: 5.2501
# Epoch 3/10
# 59362/59362 [==============================] - 4s - loss: 4.3925 - val_loss: 4.9689
# Epoch 4/10
# 59362/59362 [==============================] - 4s - loss: 4.0434 - val_loss: 4.6840
# Epoch 5/10
# 59362/59362 [==============================] - 4s - loss: 3.8176 - val_loss: 4.7109
# Epoch 6/10
# 59362/59362 [==============================] - 4s - loss: 3.6171 - val_loss: 4.5500
# Epoch 7/10
# 59362/59362 [==============================] - 4s - loss: 3.4576 - val_loss: 4.6784
# Epoch 8/10
# 59362/59362 [==============================] - 4s - loss: 3.3194 - val_loss: 4.5993
# Epoch 9/10
# 59362/59362 [==============================] - 4s - loss: 3.1885 - val_loss: 4.1248
# Epoch 10/10
# 59362/59362 [==============================] - 4s - loss: 3.1089 - val_loss: 4.0706
# Repetition 0 done.
# Model written to file: export/models/model_ae_103_128_64_8_b100_n00000_00000_ae_quat.h5

# %% [markdown]
# ### or run the cell below to load an existing model

# %%
ae_quat.load_from_file(model_storage_path + ae_quat.model_name + '.h5')

# %% [markdown]
# # Visualisations

# %% [markdown]
# ## Hand posture reconstruction

# %%
summer_school_help.print_bone_names() #  run to see bone names to be used below
# t = thumb, i = index finger, m = middle finger, r = ring finger, l = little finger
# Out:
# arm_in
# arm_out
# centre
# i1
# i2
# i3
# i4
# l1
# l2
# l3
# l4
# m1
# m2
# m3
# m4
# origin
# r1
# r2
# r3
# r4
# t1
# t2
# t3
# t4
# wrist_in
# wrist_out

# %%
# %autoreload 2
# %matplotlib inline
vis.plot_compare_reconstructed_posture(
    data=data_xyz_test, 
    metadata=meta.aalto_hand_data, 
    model=ae_xyz, 
    frames=[1000], #index/indices of frames to show
    # below: simulate missing data (set some features to zero); summer_school_help.print_bone_names() shows features 
    dropout_features=None, # e.g. missing whole thumb: ['t1','t2','t3','t4']; None for no missing features
    dropout_inputs=0, # if > 0, simulate random missing data (sets the given ratio of features to zero)
    representation=reps.REPRESENTATION_XYZ)
# Out:
# <img src="data:image/png;base64,...">

# %%
# %matplotlib inline
vis.plot_compare_reconstructed_posture(
    data=data_quat_test, 
    metadata=meta.aalto_hand_data, 
    model=ae_quat, 
    frames=[1000], 
    dropout_features=None,
    dropout_inputs=0,
    representation=reps.REPRESENTATION_QUAT)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Learned latent dimensions

# %%
vis.plot_hand_data_latent_space_ND(
    data_xyz_test.values, 
    ae_xyz, 
    alpha=0.005, lw=0, s=5)
# Out:
# <img src="data:image/png;base64,...">

# %%
vis.plot_hand_data_latent_space_ND(
    data_quat_test.values, 
    ae_quat, 
    alpha=0.005, lw=0, s=5)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Postures in learned latent dimensions

# %%
vis.plot_latent_dimensions(
    model=ae_xyz,
    data=data_xyz_test,
    metadata=meta.aalto_hand_data,
    steps=20,
    frame=1000,
    plot_static=True, plot_dynamics=False, verbose=False, 
    representation=reps.REPRESENTATION_XYZ)
# Out:
# <img src="data:image/png;base64,...">

# %%
vis.plot_latent_dimensions(
    model=ae_quat,
    data=data_quat_test,
    metadata=meta.aalto_hand_data,
    steps=20,
    frame=1000,
    plot_static=True, plot_dynamics=False, verbose=False, 
    representation=reps.REPRESENTATION_QUAT)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Posture 'derivatives' in learned latent dimensions

# %%
vis.plot_latent_dimensions(
    model=ae_xyz,
    data=data_xyz_test,
    metadata=meta.aalto_hand_data,
    steps=20,
    frame=1000,
    plot_static=False, plot_dynamics=True, verbose=False, 
    representation=reps.REPRESENTATION_XYZ)
# Out:
# <img src="data:image/png;base64,...">

# %%
vis.plot_latent_dimensions(
    model=ae_quat,
    data=data_quat_test,
    metadata=meta.aalto_hand_data,
    steps=20,
    frame=1000,
    plot_static=False, plot_dynamics=True, verbose=False, 
    representation=reps.REPRESENTATION_QUAT)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Interactive plots

# %%
# %matplotlib inline
vis.int_plot_latent_dimensions(
    model=ae_xyz,
    data=data_xyz_test,
    metadata=meta.aalto_hand_data,
    steps=20,
    frame=1000,
    representation=reps.REPRESENTATION_XYZ)

# %%
# %matplotlib inline
vis.int_plot_latent_dimensions(
    model=ae_quat,
    data=data_quat_test,
    metadata=meta.aalto_hand_data,
    steps=20,
    frame=1000,
    representation=reps.REPRESENTATION_QUAT)

# %%
# %matplotlib inline
vis.int_plot_interpolate_latent_space(
    model=ae_xyz,
    data=data_xyz_test,
    metadata=meta.aalto_hand_data,
    frame1=1000,
    frame2=2000,
    steps=20,
    representation=reps.REPRESENTATION_XYZ)

# %%
# %matplotlib inline
vis.int_plot_interpolate_latent_space(
    model=ae_quat,
    data=data_quat_test,
    metadata=meta.aalto_hand_data,
    frame1=1000,
    frame2=2000,
    steps=20,
    representation=reps.REPRESENTATION_QUAT)

# %% [markdown]
# # Evaluation

# %%
ae_eval.compute_mse(
    model=ae_xyz, # the auto encoder to evaluate
    data=data_xyz_test, # the data to reconstruct with this model
    metadata=meta.aalto_hand_data,
    input_representation=reps.REPRESENTATION_XYZ, # representation of the data given to this method
    output_representation=reps.REPRESENTATION_XYZ, # representation of the model's output
    measure_representation=reps.REPRESENTATION_QUAT) # representation on which to measure the mse
# Out:
# 0.0075464960384450924

# %%
ae_eval.compute_mse(
    model=ae_quat, 
    data=data_quat_test, 
    metadata=meta.aalto_hand_data,
    input_representation=reps.REPRESENTATION_QUAT,
    output_representation=reps.REPRESENTATION_QUAT,
    measure_representation=reps.REPRESENTATION_QUAT)
# Out:
# 0.0019503142643498349

# %%
ae_eval.compute_quat_mse(
    model=ae_quat, 
    data=data_quat_test, 
    metadata=meta.aalto_hand_data,
    input_representation=reps.REPRESENTATION_QUAT,
    output_representation=reps.REPRESENTATION_QUAT)
# Out:
# 17.927125802444017
